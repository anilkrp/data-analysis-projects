# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
print('setup complete')
# Out:
# setup complete

# %%
df = pd.read_csv('laptop_price.csv',encoding='ISO-8859-1')

# %%
df.head(7)
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       82  Ultrabook    13.3
# 1   Apple  Macbook Air       98  Ultrabook    13.3
# 2      HP       250 G6       26   Notebook    15.6
# 3   Apple  MacBook Pro       96  Ultrabook    15.4
# 4   Apple  MacBook Pro       93  Ultrabook    13.3
# 5    Acer     Aspire 3       13   Notebook    15.6
# 6   Apple  MacBook Pro       23  Ultrabook    15.4
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
# 5                            1366x768     AMD A9-Series 9420 3GHz   4GB
# ...

# %%
pp = pd.read_csv('words.txt',sep=' ')

# %%
df.columns.to_list()
# Out:
# ['laptop_ID',
#  'Company',
#  'Product',
#  'TypeName',
#  'Inches',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight',
#  'Price_euros']

# %%
df = df.drop(columns='laptop_ID')

# %%
df.columns
# Out:
# Index(['Company', 'Product', 'ran_col', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros', 'rank_ram', 'mix'],
#       dtype='object')

# %%
len(df)
# Out:
# 1303

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.iloc[:10,5:10]
# Out:
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
# 5     AMD A9-Series 9420 3GHz   4GB            500GB HDD
# 6        Intel Core i7 2.2GHz  16GB  256GB Flash Storage
# 7        Intel Core i5 1.8GHz   8GB  256GB Flash Storage
# 8  Intel Core i7 8550U 1.8GHz  16GB            512GB SSD
# 9  Intel Core i5 8250U 1.6GHz   8GB            256GB SSD
#
#                             Gpu       OpSys
# 0  Intel Iris Plus Graphics 640       macOS
# 1        Intel HD Graphics 6000       macOS
# 2         Intel HD Graphics 620       No OS
# 3            AMD Radeon Pro 455       macOS
# 4  Intel Iris Plus Graphics 650       macOS
# 5                 AMD Radeon R5  Windows 10
# ...

# %%
df.loc[[3,5,7,9],['Ram','Gpu']]
# Out:
#     Ram                     Gpu
# 3  16GB      AMD Radeon Pro 455
# 5   4GB           AMD Radeon R5
# 7   8GB  Intel HD Graphics 6000
# 9   8GB  Intel UHD Graphics 620

# %%
df.dtypes
# Out:
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.select_dtypes('object')
# Out:
#      Company                              Product            TypeName  \
# 0      Apple                          MacBook Pro           Ultrabook
# 1      Apple                          Macbook Air           Ultrabook
# 2         HP                               250 G6            Notebook
# 3      Apple                          MacBook Pro           Ultrabook
# 4      Apple                          MacBook Pro           Ultrabook
# ...      ...                                  ...                 ...
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# ...

# %%
random_col = np.random.randint(100,size=len(df))

# %%
df.insert(2,'ran_col',random_col)

# %%
df.head()
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       10  Ultrabook    13.3
# 1   Apple  Macbook Air        6  Ultrabook    13.3
# 2      HP       250 G6       90   Notebook    15.6
# 3   Apple  MacBook Pro       11  Ultrabook    15.4
# 4   Apple  MacBook Pro       52  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df['ran_col'].cumsum()
# Out:
# 0          10
# 1          16
# 2         106
# 3         117
# 4         169
#         ...
# 1298    65320
# 1299    65323
# 1300    65392
# 1301    65406
# 1302    65477
# Name: ran_col, Length: 1303, dtype: int32

# %%
df.sample(10)
# Out:
#      Company                                        Product  ran_col  \
# 383   Lenovo                             IdeaPad 720S-14IKB       88
# 1038    Dell                                 Latitude E5570       77
# 774       HP                                  EliteBook 820       79
# 711     Dell                                  Latitude 5480       54
# 683       HP                                  17-bs000nv I3       78
# 520   Lenovo                              Legion Y720-15IKB       11
# 770     Dell                                  Inspiron 5567       49
# 868     Acer  TMX349-G2-M-50FS (i5-7200U/8GB/256GB/FHD/W10)       64
# 232   Lenovo                              Legion Y720-15IKB       40
# 1008      HP                                    ProBook 440       91
#
#        TypeName  Inches             ScreenResolution  \
# 383    Notebook    14.0  IPS Panel Full HD 1920x1080
# 1038   Notebook    15.6            Full HD 1920x1080
# ...

# %%
df.sample(frac=0.1)
# Out:
#        Company                 Product  ran_col            TypeName  Inches  \
# 710     Lenovo      Legion Y520-15IKBN        2              Gaming    15.6
# 506       Asus  ZenBook UX510UX-CN211T       62            Notebook    15.6
# 1089      Acer          Aspire ES1-523       26            Notebook    15.6
# 849         HP           EliteBook 840       29           Ultrabook    14.0
# 981    Toshiba       Portege Z30-C-1CV       68            Notebook    13.3
# ...        ...                     ...      ...                 ...     ...
# 626   Mediacom           SmartBook 140       54            Notebook    14.0
# 264       Dell           Inspiron 3567       81            Notebook    15.6
# 723       Dell            Alienware 17       19              Gaming    17.3
# 1270    Lenovo          Yoga 500-14ISK       74  2 in 1 Convertible    14.0
# 621     Lenovo           ThinkPad T470       78            Notebook    14.0
#
# ...

# %%
df[df['ran_col'] > 60]
# Out:
#      Company                              Product  ran_col  \
# 2         HP                               250 G6       90
# 5       Acer                             Aspire 3       86
# 9       Acer                              Swift 3       81
# 11        HP                               250 G6       89
# 13      Dell                        Inspiron 3567       64
# ...      ...                                  ...      ...
# 1295    Dell                        Inspiron 3567       77
# 1296      HP                     Stream 11-Y000na       66
# 1298  Lenovo                       Yoga 500-14ISK       80
# 1300  Lenovo                   IdeaPad 100S-14IBR       69
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)       71
#
#                 TypeName  Inches                           ScreenResolution  \
# 2               Notebook    15.6                          Full HD 1920x1080
# 5               Notebook    15.6                                   1366x768
# ...

# %%
df.ran_col.nunique()
# Out:
# 100

# %%
df.nunique()
# Out:
# Company              19
# Product             618
# ran_col             100
# TypeName              6
# Inches               18
# ScreenResolution     40
# Cpu                 118
# Ram                   9
# Memory               39
# Gpu                 110
# OpSys                 9
# Weight              179
# Price_euros         791
# dtype: int64

# %%
df['rank_ram'] = df.Ram.rank()

# %%
df.head()
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       10  Ultrabook    13.3
# 1   Apple  Macbook Air        6  Ultrabook    13.3
# 2      HP       250 G6       90   Notebook    15.6
# 3   Apple  MacBook Pro       11  Ultrabook    15.4
# 4   Apple  MacBook Pro       52  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
l_ram = ['8GB','16GB','4GB']
df[df.Ram.isin(l_ram)]
# Out:
#      Company                                    Product  ran_col  \
# 0      Apple                                MacBook Pro       10
# 1      Apple                                Macbook Air        6
# 2         HP                                     250 G6       90
# 3      Apple                                MacBook Pro       11
# 4      Apple                                MacBook Pro       52
# ...      ...                                        ...      ...
# 1295    Dell                              Inspiron 3567       77
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce       45
# 1298  Lenovo                             Yoga 500-14ISK       80
# 1299  Lenovo                             Yoga 900-13ISK        3
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)       71
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.groupby('OpSys')['Ram'].sum()
# Out:
# OpSys
# Android                                                    4GB4GB
# Chrome OS       2GB4GB4GB16GB8GB4GB4GB4GB8GB4GB4GB2GB8GB4GB4GB...
# Linux           4GB4GB8GB4GB12GB8GB4GB8GB16GB8GB8GB16GB4GB8GB8...
# Mac OS X                                16GB8GB8GB8GB8GB8GB8GB4GB
# No OS           8GB4GB4GB8GB4GB4GB8GB8GB8GB4GB4GB4GB8GB4GB8GB8...
# Windows 10      4GB16GB8GB4GB8GB8GB2GB8GB8GB8GB4GB8GB8GB8GB4GB...
# Windows 10 S                            4GB8GB4GB16GB4GB8GB4GB8GB
# Windows 7       8GB8GB4GB16GB16GB8GB16GB8GB8GB4GB4GB8GB16GB8GB...
# macOS                  8GB8GB16GB8GB8GB16GB8GB8GB16GB8GB8GB8GB8GB
# Name: Ram, dtype: object

# %%
df.Price_euros.pct_change()
# Out:
# 0            NaN
# 1      -0.328994
# 2      -0.360358
# 3       3.412957
# 4      -0.289208
#           ...
# 1298   -0.114283
# 1299    1.349530
# 1300   -0.847231
# 1301    2.336245
# 1302   -0.517016
# Name: Price_euros, Length: 1303, dtype: float64

# %%
df.nlargest(5,'Price_euros')
# Out:
#      Company       Product  ran_col     TypeName  Inches  \
# 196    Razer     Blade Pro       36       Gaming    17.3
# 830    Razer     Blade Pro       37       Gaming    17.3
# 610   Lenovo  Thinkpad P51       50     Notebook    15.6
# 749       HP      Zbook 17       26  Workstation    17.3
# 1066    Asus    ROG G701VO        1       Gaming    17.3
#
#                          ScreenResolution                            Cpu  \
# 196   4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz
# 830   4K Ultra HD / Touchscreen 3840x2160    Intel Core i7 7820HK 2.9GHz
# 610       IPS Panel 4K Ultra HD 3840x2160  Intel Xeon E3-1535M v6 3.1GHz
# 749           IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz
# 1066          IPS Panel Full HD 1920x1080    Intel Core i7 6820HK 2.7GHz
#
#        Ram     Memory                      Gpu       OpSys  Weight  \
# 196   32GB    1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg
# ...

# %%
df = df.assign(mix = df.ran_col ** 2)

# %%
df.head()
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       10  Ultrabook    13.3
# 1   Apple  Macbook Air        6  Ultrabook    13.3
# 2      HP       250 G6       90   Notebook    15.6
# 3   Apple  MacBook Pro       11  Ultrabook    15.4
# 4   Apple  MacBook Pro       52  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df[df.ran_col == 10]
# Out:
#      Company                 Product  ran_col            TypeName  Inches  \
# 0      Apple             MacBook Pro       10           Ultrabook    13.3
# 91      Acer                Aspire 5       10            Notebook    15.6
# 125       HP                  250 G6       10            Notebook    15.6
# 131     Dell           Inspiron 3567       10            Notebook    15.6
# 214   Huawei              MateBook X       10           Ultrabook    13.0
# 253   Lenovo          Yoga 920-13IKB       10  2 in 1 Convertible    13.9
# 258      MSI             GT73EVR 7RE       10              Gaming    17.3
# 324     Acer                Aspire 5       10            Notebook    15.6
# 532     Asus  Zenbook UX510UW-FI095T       10            Notebook    15.6
# 979     Asus        Rog GL753VE-DS74       10              Gaming    17.3
# 1091      HP                  250 G6       10            Notebook    15.6
#
#                                ScreenResolution  \
# ...

# %%
df[df.ran_col.isin([10])]
# Out:
#      Company                 Product  ran_col            TypeName  Inches  \
# 0      Apple             MacBook Pro       10           Ultrabook    13.3
# 91      Acer                Aspire 5       10            Notebook    15.6
# 125       HP                  250 G6       10            Notebook    15.6
# 131     Dell           Inspiron 3567       10            Notebook    15.6
# 214   Huawei              MateBook X       10           Ultrabook    13.0
# 253   Lenovo          Yoga 920-13IKB       10  2 in 1 Convertible    13.9
# 258      MSI             GT73EVR 7RE       10              Gaming    17.3
# 324     Acer                Aspire 5       10            Notebook    15.6
# 532     Asus  Zenbook UX510UW-FI095T       10            Notebook    15.6
# 979     Asus        Rog GL753VE-DS74       10              Gaming    17.3
# 1091      HP                  250 G6       10            Notebook    15.6
#
#                                ScreenResolution  \
# ...

# %%
df.head()
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       10  Ultrabook    13.3
# 1   Apple  Macbook Air        6  Ultrabook    13.3
# 2      HP       250 G6       90   Notebook    15.6
# 3   Apple  MacBook Pro       11  Ultrabook    15.4
# 4   Apple  MacBook Pro       52  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.describe()
# Out:
#            ran_col       Inches  Price_euros     rank_ram          mix
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     50.250959    15.017191  1123.686992   652.000000  3332.688411
# std      28.427974     1.426304   699.009043   350.026877  2918.977396
# min       0.000000    10.100000   174.000000    13.000000     0.000000
# 25%      26.000000    14.000000   599.000000   455.000000   676.000000
# 50%      51.000000    15.600000   977.000000   664.000000  2601.000000
# 75%      75.000000    15.600000  1487.880000   994.000000  5625.000000
# max      99.000000    18.400000  6099.000000   994.000000  9801.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   ran_col           1303 non-null   int32
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
#  13  rank_ram          1303 non-null   float64
#  14  mix               1303 non-null   int32
# dtypes: float64(3), int32(2), object(10)
# memory usage: 142.6+ KB

# %%
df.isna().sum()
# Out:
# Company             0
# Product             0
# ran_col             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# rank_ram            0
# mix                 0
# dtype: int64

# %%
df.sort_values('ran_col').head(2)
# Out:
#      Company        Product  ran_col            TypeName  Inches  \
# 30     Chuwi  LapBook 15.6"        0            Notebook    15.6
# 1140  Lenovo    ThinkPad X1        0  2 in 1 Convertible    14.0
#
#                      ScreenResolution                          Cpu   Ram  \
# 30                  Full HD 1920x1080  Intel Atom x5-Z8300 1.44GHz   4GB
# 1140  IPS Panel Touchscreen 2560x1440   Intel Core i7 6600U 2.6GHz  16GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 30    64GB Flash Storage      Intel HD Graphics  Windows 10  1.89kg
# 1140           512GB SSD  Intel HD Graphics 520  Windows 10   2.8kg
#
#       Price_euros  rank_ram  mix
# 30         244.99     455.0    0
# 1140      2440.00     125.5    0

# %%
df.ran_col.value_counts().sort_values().tail()
# Out:
# 95    20
# 64    21
# 78    22
# 54    22
# 57    22
# Name: ran_col, dtype: int64

# %%
df.loc[11,['ran_col']]
# Out:
# ran_col    89
# Name: 11, dtype: object

# %%
df.iloc[9]
# Out:
# Company                                    Acer
# Product                                 Swift 3
# ran_col                                      81
# TypeName                              Ultrabook
# Inches                                     14.0
# ScreenResolution    IPS Panel Full HD 1920x1080
# Cpu                  Intel Core i5 8250U 1.6GHz
# Ram                                         8GB
# Memory                                256GB SSD
# Gpu                      Intel UHD Graphics 620
# OpSys                                Windows 10
# Weight                                    1.6kg
# Price_euros                               770.0
# rank_ram                                  994.0
# mix                                        6561
# Name: 9, dtype: object

# %%
df.mix = df.mix.apply(lambda x : x*3)

# %%
df.mix = df.mix.apply(lambda x : np.sqrt(x))

# %%
df.mix
# Out:
# 0        17.320508
# 1        10.392305
# 2       155.884573
# 3        19.052559
# 4        90.066642
#            ...
# 1298    138.564065
# 1299      5.196152
# 1300    119.511506
# 1301     24.248711
# 1302    122.975607
# Name: mix, Length: 1303, dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.value_counts('ran_col')
# Out:
# ran_col
# 57    22
# 54    22
# 78    22
# 64    21
# 95    20
#       ..
# 83     8
# 28     7
# 58     7
# 5      7
# 31     4
# Length: 100, dtype: int64

# %%
pd.read_csv('laptop_price.csv',usecols=['Cpu','Ram'],index_col='Ram',encoding='ISO-8859-1')
# Out:
#                                        Cpu
# Ram
# 8GB                   Intel Core i5 2.3GHz
# 8GB                   Intel Core i5 1.8GHz
# 8GB             Intel Core i5 7200U 2.5GHz
# 16GB                  Intel Core i7 2.7GHz
# 8GB                   Intel Core i5 3.1GHz
# ...                                    ...
# 4GB             Intel Core i7 6500U 2.5GHz
# 16GB            Intel Core i7 6500U 2.5GHz
# 2GB   Intel Celeron Dual Core N3050 1.6GHz
# 6GB             Intel Core i7 6500U 2.5GHz
# 4GB   Intel Celeron Dual Core N3050 1.6GHz
#
# [1303 rows x 1 columns]

# %%
df.select_dtypes(include='number')
# Out:
#       ran_col  Inches  Price_euros  rank_ram         mix
# 0          82    13.3      1339.69     994.0  142.028166
# 1          98    13.3       898.94     994.0  169.740979
# 2          26    15.6       575.00     994.0   45.033321
# 3          96    15.4      2537.45     125.5  166.276878
# 4          93    13.3      1803.60     994.0  161.080725
# ...       ...     ...          ...       ...         ...
# 1298       82    14.0       638.00     455.0  142.028166
# 1299       19    13.3      1499.00     125.5   32.908965
# 1300       97    14.0       229.00     239.5  168.008928
# 1301       19    15.6       764.00     664.0   32.908965
# 1302       23    15.6       369.00     455.0   39.837169
#
# [1303 rows x 5 columns]

# %%
df['size_enough'] = np.where(df['Inches']> 14, 'good','normal')

# %%
df.head()
# Out:
#   Company      Product  ran_col   TypeName  Inches  \
# 0   Apple  MacBook Pro       82  Ultrabook    13.3
# 1   Apple  Macbook Air       98  Ultrabook    13.3
# 2      HP       250 G6       26   Notebook    15.6
# 3   Apple  MacBook Pro       96  Ultrabook    15.4
# 4   Apple  MacBook Pro       93  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...
