# %%
project_name = "zerotopandas-course-project-starter" # change this (use lowercase letters and hyphens only)

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Updating notebook "anilkrp/zerotopandas-course-project-starter" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/anilkrp/zerotopandas-course-project-starter
# 'https://jovian.ai/anilkrp/zerotopandas-course-project-starter'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('1976-2020-president.csv')

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# ...

# %%
df.shape
# Out:
# (4287, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4287 non-null   int64
#  1   state             4287 non-null   object
#  2   state_po          4287 non-null   object
#  3   state_fips        4287 non-null   int64
#  4   state_cen         4287 non-null   int64
#  5   state_ic          4287 non-null   int64
#  6   office            4287 non-null   object
#  7   candidate         4000 non-null   object
#  8   party_detailed    3831 non-null   object
#  9   writein           4284 non-null   object
#  10  candidatevotes    4287 non-null   int64
#  11  totalvotes        4287 non-null   int64
#  12  version           4287 non-null   int64
#  13  notes             0 non-null      float64
#  14  party_simplified  4287 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 502.5+ KB

# %%
df.describe()
# Out:
#               year   state_fips    state_cen     state_ic  candidatevotes  \
# count  4287.000000  4287.000000  4287.000000  4287.000000    4.287000e+03
# mean   1999.080942    28.616982    53.665034    39.754840    3.119076e+05
# std      14.220014    15.616459    26.029189    22.772216    7.648011e+05
# min    1976.000000     1.000000    11.000000     1.000000    0.000000e+00
# 25%    1988.000000    16.000000    33.000000    22.000000    1.177000e+03
# 50%    2000.000000    28.000000    53.000000    42.000000    7.499000e+03
# 75%    2012.000000    41.000000    81.000000    61.000000    1.992415e+05
# max    2020.000000    56.000000    95.000000    82.000000    1.111025e+07
#
#          totalvotes     version  notes
# count  4.287000e+03      4287.0    0.0
# mean   2.366924e+06  20210113.0    NaN
# std    2.465008e+06         0.0    NaN
# min    1.235740e+05  20210113.0    NaN
# 25%    6.522740e+05  20210113.0    NaN
# 50%    1.569180e+06  20210113.0    NaN
# ...

# %%
df.isnull().sum()
# Out:
# year                   0
# state                  0
# state_po               0
# state_fips             0
# state_cen              0
# state_ic               0
# office                 0
# candidate            287
# party_detailed       456
# writein                3
# candidatevotes         0
# totalvotes             0
# version                0
# notes               4287
# party_simplified       0
# dtype: int64

# %%
df.drop(columns=('notes'),inplace=True)

# %%
df.party_detailed.value_counts()
# Out:
# REPUBLICAN                   613
# DEMOCRAT                     612
# LIBERTARIAN                  535
# INDEPENDENT                  405
# GREEN                        211
#                             ...
# NATURAL PEOPLE'S LEAGUE        1
# VERMONT GRASSROOTS             1
# PROGRESSIVE/GREEN              1
# UNITED SOVEREIGN CITIZENS      1
# APPROVAL VOTING                1
# Name: party_detailed, Length: 172, dtype: int64

# %%
df.candidate.value_counts()
# Out:
# NADER, RALPH              137
# OTHER                     106
# BUSH, GEORGE H.W.         105
# OBAMA, BARACK H.          104
# BUSH, GEORGE W.           104
#                          ...
# UNAFFILIATED                1
# DANIELS, RONALD             1
# YIAMOUYIANNIS, JOHN         1
# CUMMINGS, DANIEL CLYDE      1
# SCALF, ZACHARY              1
# Name: candidate, Length: 270, dtype: int64

# %%
df[df.isnull().values]
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, office, candidate, party_detailed, writein, candidatevotes, totalvotes, version, party_simplified]
# Index: []

# %%
df=df.dropna()

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version party_simplified
# 0          659170     1182850  20210113         DEMOCRAT
# ...

# %%
df.writein.value_counts()
# Out:
# False    3611
# True      143
# Name: writein, dtype: int64

# %%
df.writein=df.writein.map({False:0,True:1})

# %%
df.writein.value_counts()
# Out:
# 0    3611
# 1     143
# Name: writein, dtype: int64

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "anilkrp/zerotopandas-course-project-starter" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/anilkrp/zerotopandas-course-project-starter
# 'https://jovian.ai/anilkrp/zerotopandas-course-project-starter'

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df.party_simplified.value_counts()
# Out:
# OTHER          1993
# DEMOCRAT        614
# REPUBLICAN      613
# LIBERTARIAN     534
# Name: party_simplified, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3754 entries, 0 to 4283
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              3754 non-null   int64
#  1   state             3754 non-null   object
#  2   state_po          3754 non-null   object
#  3   state_fips        3754 non-null   int64
#  4   state_cen         3754 non-null   int64
#  5   state_ic          3754 non-null   int64
#  6   office            3754 non-null   object
#  7   candidate         3754 non-null   object
#  8   party_detailed    3754 non-null   object
#  9   writein           3754 non-null   int64
#  10  candidatevotes    3754 non-null   int64
#  11  totalvotes        3754 non-null   int64
#  12  version           3754 non-null   int64
#  13  party_simplified  3754 non-null   object
# dtypes: int64(8), object(6)
# memory usage: 569.0+ KB

# %%
df.party_simplified.value_counts().plot(kind='bar')
plt.title('Number of parties')
# Out:
# Text(0.5, 1.0, 'Number of parties')

# %%
# it is graph about number of parities over the timeperirod

# %%
sns.pairplot(df)

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "anilkrp/zerotopandas-course-project-starter" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/anilkrp/zerotopandas-course-project-starter
# 'https://jovian.ai/anilkrp/zerotopandas-course-project-starter'

# %%
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed  writein  \
# 0            CARTER, JIMMY                    DEMOCRAT        0
# 1             FORD, GERALD                  REPUBLICAN        0
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY        0
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION        0
# 4                HALL, GUS         COMMUNIST PARTY USE        0
#
#    candidatevotes  totalvotes   version party_simplified
# 0          659170     1182850  20210113         DEMOCRAT
# ...

# %%
sns.scatterplot(x=df.state_cen,y=df.state_ic)
# graph between state_cen v/s state_ic
# Out:
# <AxesSubplot: xlabel='state_cen', ylabel='state_ic'>

# %%
# top candidate with voters
df.sort_values(by='totalvotes',ascending=False).head()
# Out:
#       year       state state_po  state_fips  state_cen  state_ic  \
# 3774  2020  CALIFORNIA       CA           6         93        71
# 3777  2020  CALIFORNIA       CA           6         93        71
# 3773  2020  CALIFORNIA       CA           6         93        71
# 3783  2020  CALIFORNIA       CA           6         93        71
# 3781  2020  CALIFORNIA       CA           6         93        71
#
#             office                      candidate        party_detailed  \
# 3774  US PRESIDENT               TRUMP, DONALD J.            REPUBLICAN
# 3777  US PRESIDENT  DE LA FUENTE, ROQUE ""ROCKY""  AMERICAN INDEPENDENT
# 3773  US PRESIDENT            BIDEN, JOSEPH R. JR              DEMOCRAT
# 3783  US PRESIDENT                 JOSEPH KISHORE           INDEPENDENT
# 3781  US PRESIDENT                   MARK CHARLES           INDEPENDENT
#
#       writein  candidatevotes  totalvotes   version party_simplified
# 3774        0         6006429    17500881  20210113       REPUBLICAN
# ...

# %%
# top states who win many times
df.state.value_counts().plot(kind = 'bar')
plt.title('top states who win many times')
plt.ylabel('number')
# Out:
# Text(0, 0.5, 'number')

# %%
# top 10 candidate who become us president
df.candidate.value_counts().head(10)
# Out:
# NADER, RALPH         137
# BUSH, GEORGE H.W.    105
# REAGAN, RONALD       104
# OBAMA, BARACK H.     104
# CLINTON, BILL        104
# TRUMP, DONALD J.     104
# BUSH, GEORGE W.      104
# CARTER, JIMMY        103
# PEROT, ROSS           98
# JOHNSON, GARY         96
# Name: candidate, dtype: int64

# %%
# top 10 state_fips
df.state_fips.value_counts().head(10)
# Out:
# 8     147
# 36    118
# 27    115
# 19    106
# 50    106
# 49    104
# 53    102
# 34    102
# 22    101
# 5      89
# Name: state_fips, dtype: int64

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "anilkrp/zerotopandas-course-project-starter" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/anilkrp/zerotopandas-course-project-starter
# 'https://jovian.ai/anilkrp/zerotopandas-course-project-starter'
